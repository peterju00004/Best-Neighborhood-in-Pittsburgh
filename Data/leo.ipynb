# %% [markdown]
# # Hypertension By Neighborhoods
# ## by Leo Liang

# %%
import geopandas as gpd
import pandas as pd

Allegheny_County = gpd.read_file("hypertension.csv")

Allegheny_County.head(10)
# Out:
#        CT LTPAD LTPAN LTWAD LTWAN LTMAD LTMAN geometry
# 0  473401  1922   193  1000    94   922    99     None
# 1  450800   995   222   541   124   454    98     None
# 2  455000   768   181   393    83   375    98     None
# 3  101800  1383   218   777   121   606    97     None
# 4  401200  1116   247   617   150   499    97     None
# 5  479000  1101   202   601   106   500    96     None
# 6  141300  1998   195  1056    99   942    96     None
# 7  424000  1577   224   887   129   690    95     None
# 8  435000  1228   189   647    94   581    95     None
# 9  474201  1452   170   752    76   700    94     None

# %%
shape = gpd.read_file("pittsburghpaneighborhoods-/Neighborhoods_.shp")
shape.head(15)
# Out:
#     OBJECTID  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0          1         233        42        003    140500          3
# 1          2         203        42        003    140100          3
# 2          3          86        42        003    101700          2
# 3          4         214        42        003    050900          1
# 4          5         173        42        003    300100          5
# 5          6         286        42        003    130400          3
# 6          7         348        42        003    050100          3
# 7          8         313        42        003    562800          2
# 8          9           1        42        003    040400          1
# 9         10          77        42        003    191100          2
# 10        11          96        42        003    562300          2
# 11        12         321        42        003    111500          4
# 12        13          13        42        003    563100          2
# ...
